# %%
import requests
import pandas as pd
import numpy as np
from pandasql import sqldf

import json
from geopy.geocoders import Nominatim
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import folium

# %%
CLIENT_ID = 'LZXKKR3DROVZZCAMQWVB0EVBRJH5URYIPI3EE5V54KHNGUAF' 
CLIENT_SECRET = 'SFMKJVVYDBZJYOLJOWM0FY0MSTOLAKAPYGDHT4UMXBVELY4K'
VERSION = '20200402'
LIMIT = 100

address = "Seoul, Korea"

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude =location.latitude
longitude =location.longitude
print('Location : {},{}'.format(latitude,longitude))
# Out:
# Location : 37.5666791,126.9782914

# %%
search_query_list = ['park','temple','church','shop','university','store'
                    'office','company'] #venues
radius =1000
temp_df=[]
search_df=[]

def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

for i in range(len(search_query_list)):
    url= 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query_list[i], radius, LIMIT)
    results=requests.get(url).json()
    venues = results['response']['venues']
    dataframe = json_normalize(venues)
    dataframe.columns = [col.split('.')[-1] for col in dataframe.columns]
    temp_df.append(dataframe)
    
for j in range(len(search_query_list)):
    data=temp_df[j]
    search_df.append(data)

search_df = pd.concat(search_df,sort=True)
search_df['categories'] = search_df.apply(get_category_type, axis=1)
search_df = pd.DataFrame(search_df[['name','categories','distance','lat','lng','id']])
# Out:
# /Users/abhigupta/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead

# %%
pd.options.display.max_rows=None
pd.options.display.max_columns=None

sqldf('''
select distinct ifnull(categories,name) categories from search_df order by 1
''', locals())
# Out:
#                                   categories
# 0                             Adult Boutique
# 1                        American Restaurant
# 2                        Arts & Crafts Store
# 3                            Assisted Living
# 4                                     Bakery
# 5                                   Beer Bar
# 6                                Beer Garden
# 7           Bishop Sundo Kim Memorial Church
# 8                                   Boutique
# 9                            Buddhist Temple
# 10                                  Building
# 11                              Burger Joint
# 12                                  Bus Stop
# 13                                 Cafeteria
# 14                                      Café
# 15                              Camera Store
# 16                                    Church
# 17                            Clothing Store
# 18                               Coffee Shop
# 19           College Administrative Building
# 20                         College Bookstore
# 21                               College Gym
# 22                    College Residence Hall
# 23                            Cosmetics Shop
# 24                           Coworking Space
# 25                           Cultural Center
# 26                          Dentist's Office
# 27                          Department Store
# 28                            Duty-free Shop
# 29                         Electronics Store
# 30                       Embassy / Consulate
# 31  Filipino-Korean International SDA Church
# 32                Financial or Legal Service
# 33                                Food Truck
# 34                               Gaming Cafe
# 35              General College & University
# 36                                 Gift Shop
# 37                             Grocery Store
# 38                                       Gym
# 39                    Hallasan Natuinal Park
# 40                   Health & Beauty Service
# 41                             Historic Site
# 42                                  Hospital
# 43                                     Hotel
# 44                        Italian Restaurant
# 45                             Knitting Shop
# 46                         Korean Restaurant
# 47                           Laundry Service
# 48                                    Market
# 49                            Massage Studio
# 50                                 Mini Golf
# 51                         Mobile Phone Shop
# 52                               Music Store
# 53                                Nail Salon
# 54                                    Office
# 55                              Optical Shop
# 56                                      Park
# 57                                   Parking
# 58                          Pedestrian Plaza
# 59                                     Plaza
# 60  Residential Building (Apartment / Condo)
# 61                                      Road
# 62                        Salon / Barbershop
# 63                            Sandwich Place
# 64            Seung Dong Presbyterian Church
# 65                               Shoe Repair
# 66                            Shop & Service
# 67                             Souvenir Shop
# 68                                       Spa
# 69                          Stationery Store
# 70                                Steakhouse
# 71                               Tailor Shop
# 72               The Coca-Cola Korea Company
# 73                Tourist Information Center
# 74                          Toy / Game Store
# 75                              Trade School

# %%
df_venues = sqldf('''
select * from search_df 
where ifnull(categories,name) not in ('Road','Café') order by 1
''', locals())
df_venues.shape
# Out:
# (137, 6)

# %%
df_venues.head(10)
# Out:
#                                  name                    categories  distance  \
# 0                    117Park (117 파크)                    Steakhouse       859
# 1     American Orientalism University  General College & University       869
# 2          Artxstay Co-Working & Shop               Coworking Space       142
# 3                         BARBER SHOP            Salon / Barbershop       729
# 4           BASF the chemical company                        Office       781
# 5                BATTERY PARK (배터리파크)           American Restaurant       825
# 6       Bain & Company (베인앤드컴퍼니코리아인크)    Financial or Legal Service       827
# 7  Bethany Internasional Church Korea                        Church       817
# 8       Bike Repair Shop by Bean Pole                Clothing Store       343
# 9    Bishop Sundo Kim Memorial Church                          None       945
#
#          lat         lng                        id
# 0  37.571564  126.970742  562762c0498e66b48b709412
# 1  37.572609  126.984699  551f44a4498e60974d9d3c59
# 2  37.565425  126.978628  5b5fca3c031320002cfc1fbe
# 3  37.563296  126.985369  51cd2fd3498ecf5841e193bb
# 4  37.560566  126.973927  4ffbfa20e4b0283dcdb0b3e1
# 5  37.560399  126.983277  5195f7b7498edc6527ea1208
# 6  37.560194  126.982877  4d40f274aae1b1f7bbe78bf5
# 7  37.559361  126.979027  51fe068c498e09e91725d2b1
# 8  37.563846  126.979821  5261ee0a11d25d0c24b41772
# 9  37.566899  126.989006  5798d31f498ec17c920b21f4

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, label in zip(df_venues.lat, df_venues.lng, df_venues.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill = True,
        fill_color='#3186cc',
        fill_opacity=0.7
    ).add_to(venues_map)
    
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
kclusters = 3
kmeans = KMeans(n_clusters = kclusters, init ='k-means++')
kmeans.fit(df_venues[['lat','lng']])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
df_venues['label'] = kmeans.fit_predict(df_venues[['lat','lng']])
df_venues.head(10)
# Out:
#                                  name                    categories  distance  \
# 0                    117Park (117 파크)                    Steakhouse       859
# 1     American Orientalism University  General College & University       869
# 2          Artxstay Co-Working & Shop               Coworking Space       142
# 3                         BARBER SHOP            Salon / Barbershop       729
# 4           BASF the chemical company                        Office       781
# 5                BATTERY PARK (배터리파크)           American Restaurant       825
# 6       Bain & Company (베인앤드컴퍼니코리아인크)    Financial or Legal Service       827
# 7  Bethany Internasional Church Korea                        Church       817
# 8       Bike Repair Shop by Bean Pole                Clothing Store       343
# 9    Bishop Sundo Kim Memorial Church                          None       945
#
#          lat         lng                        id  label
# 0  37.571564  126.970742  562762c0498e66b48b709412      2
# 1  37.572609  126.984699  551f44a4498e60974d9d3c59      0
# 2  37.565425  126.978628  5b5fca3c031320002cfc1fbe      1
# 3  37.563296  126.985369  51cd2fd3498ecf5841e193bb      1
# 4  37.560566  126.973927  4ffbfa20e4b0283dcdb0b3e1      1
# 5  37.560399  126.983277  5195f7b7498edc6527ea1208      1
# 6  37.560194  126.982877  4d40f274aae1b1f7bbe78bf5      1
# 7  37.559361  126.979027  51fe068c498e09e91725d2b1      1
# 8  37.563846  126.979821  5261ee0a11d25d0c24b41772      1
# 9  37.566899  126.989006  5798d31f498ec17c920b21f4      0

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=14)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

for lat, lng, cluster in zip(df_venues.lat, df_venues.lng, df_venues.label):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
#         popup=label,
        color=rainbow[int(cluster-1)],
        fill=True,
        fill_color=rainbow[int(cluster-1)],
        fill_opacity=0.5
    ).add_to(venues_map)
    
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
centers = kmeans.cluster_centers_
centers
# Out:
# array([[ 37.57034026, 126.98548194],
#        [ 37.56178858, 126.98123811],
#        [ 37.56998364, 126.97256867]])

# %%
search_query_list = ['coffee']
radius =100
temp_df=[]
search_df=[]

for i in range(len(search_query_list)):
    url= 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(
        CLIENT_ID, CLIENT_SECRET, centers[0][0], centers[0][1], VERSION, search_query_list[i], radius, LIMIT)
    results=requests.get(url).json()
    venues = results['response']['venues']
    dataframe = json_normalize(venues)
    dataframe.columns = [col.split('.')[-1] for col in dataframe.columns]
    temp_df.append(dataframe)
    
for j in range(len(search_query_list)):
    data=temp_df[j]
    search_df.append(data)

search_df = pd.concat(search_df,sort=True)
search_df['categories'] = search_df.apply(get_category_type, axis=1)
search_df = pd.DataFrame(search_df[['name','categories','distance','lat','lng','id']])
search_df
# Out:
# /Users/abhigupta/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # This is added back by InteractiveShellApp.init_path()
#                          name   categories  distance        lat         lng  \
# 0  The Coffee Bean & Tea Leaf  Coffee Shop        48  37.570004  126.985128
# 1                EDIYA COFFEE  Coffee Shop        18  37.570435  126.985648
# 2                EDIYA COFFEE  Coffee Shop        35  37.570454  126.985856
# 3                 Mare coffee  Coffee Shop       100  37.569491  126.985085
# 4          Angel-in-us Coffee  Coffee Shop       113  37.569390  126.985945
# 5        That’s Coffee Jongro  Coffee Shop       134  37.569142  126.985639
# 6            Starbucks (스타벅스)  Coffee Shop        94  37.569944  126.984535
#
#                          id
# 0  58e7159fe386e3088f77cc8a
# 1  4da805fda86e68edb7d38d8a
# 2  50176fc8e4b02c99f918848b
# 3  4bdfa7956198c9b6741318ff
# 4  4d9196d856a3f04d03d4e641
# 5  5b440e39dd70c50039b1c859
# 6  4b48453ff964a520dd4a26e3

# %%
search_query_list = ['coffee']
radius =100
temp_df=[]
search_df=[]

for i in range(len(search_query_list)):
    url= 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(
        CLIENT_ID, CLIENT_SECRET, centers[1][0], centers[1][1], VERSION, search_query_list[i], radius, LIMIT)
    results=requests.get(url).json()
    venues = results['response']['venues']
    dataframe = json_normalize(venues)
    dataframe.columns = [col.split('.')[-1] for col in dataframe.columns]
    temp_df.append(dataframe)
    
for j in range(len(search_query_list)):
    data=temp_df[j]
    search_df.append(data)

search_df = pd.concat(search_df,sort=True)
search_df['categories'] = search_df.apply(get_category_type, axis=1)
search_df = pd.DataFrame(search_df[['name','categories','distance','lat','lng','id']])
search_df
# Out:
# /Users/abhigupta/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # This is added back by InteractiveShellApp.init_path()
#                              name   categories  distance        lat  \
# 0                     COFFEE 1896         Café       127  37.562140
# 1            Gloria Jean's Coffee  Coffee Shop        90  37.561694
# 2  Espreso coffee Rosebird 중앙클리닉점  Coffee Shop        62  37.561633
# 3                  Barista Coffee  Coffee Shop        98  37.561371
# 4        TOM N TOMS COFFEE (탐앤탐스)  Coffee Shop       123  37.560985
# 5                         Mon-Ami         Café       106  37.561692
# 6             Paik's Coffee (빽다방)  Coffee Shop        84  37.562422
#
#           lng                        id
# 0  126.982615  5112422fe4b0042c195f5f3d
# 1  126.982258  4e6822b4fa76aa094cef7250
# 2  126.981921  4e1d0cdbb0fb93d2d05f6eb4
# 3  126.980253  4bf0bce16f8aa5935140c23c
# 4  126.982201  4b8b5459f964a5206f9c32e3
# 5  126.982441  531d56bf498e5e1636c9e4fd
# 6  126.981761  567b670f498ea638f1c5b8ec

# %%
search_query_list = ['coffee']
radius =100
temp_df=[]
search_df=[]

for i in range(len(search_query_list)):
    url= 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(
        CLIENT_ID, CLIENT_SECRET, centers[2][0], centers[2][1], VERSION, search_query_list[i], radius, LIMIT)
    results=requests.get(url).json()
    venues = results['response']['venues']
    dataframe = json_normalize(venues)
    dataframe.columns = [col.split('.')[-1] for col in dataframe.columns]
    temp_df.append(dataframe)
    
for j in range(len(search_query_list)):
    data=temp_df[j]
    search_df.append(data)

search_df = pd.concat(search_df,sort=True)
search_df['categories'] = search_df.apply(get_category_type, axis=1)
search_df = pd.DataFrame(search_df[['name','categories','distance','lat','lng','id']])
search_df
# Out:
# /Users/abhigupta/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # This is added back by InteractiveShellApp.init_path()
#                     name   categories  distance        lat         lng  \
# 0  HOLLYS COFFEE (할리스커피)  Coffee Shop       110  37.569690  126.971376
# 1         Get Out Coffee         Café        53  37.570167  126.973135
#
#                          id
# 0  4cad5fba632b3704d4df666e
# 1  53193ee8498e1c63927a9f3f

# %%
##The location for New coffee shop will be nearby the third center, which is 37.56991121, 126.97279993
